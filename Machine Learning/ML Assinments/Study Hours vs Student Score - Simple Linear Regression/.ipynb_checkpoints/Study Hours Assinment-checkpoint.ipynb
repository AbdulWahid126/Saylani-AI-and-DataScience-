# %% [markdown]
# ### Q: Is dataset par aap study hours ke basis par student ke scores predict karein ge using Simple Linear Regression. Complete ML workflow follow karein including preprocessing, training aur evaluation?

# %%
import pandas as pd

# %%
data = pd.read_csv("rounded_hours_student_scores.csv")
data.head()
# Out:
#    Hours  Scores
# 0    1.1      41
# 1    1.2      40
# 2    1.4      38
# 3    1.5      39
# 4    1.6      36
